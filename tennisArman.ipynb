# %% [markdown]
# # Dependencies
# * Installing `pyarrow` is needed for parquet support

# %%
! pip install pyarrow

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %% [markdown]
# # Reading Data
# * Since our data is in parquet format, we need to loop over our data to have them in dataframes
#
#     1. Extracting Table Names using `os.listdir`
#
#     2. Creating a dictionary with keys for each table and appending table parquet files as a list for each key
#
#     3. Reading each parquet file for each table and creating a dictionary for each dataframe with table names to concatenate them afterwards
#
#     4. Concatenating each dataframe value and creating a dataframe with relevant name for the table and saving the dataframe as a csv file to be able to use later and share with the team

# %%
BASE_DIR = 'tennis_data_20231212/raw/'
folders = os.listdir(BASE_DIR)
folders
# Out:
# ['raw_match_parquet',
#  'raw_odds_parquet',
#  'raw_point_by_point_parquet',
#  'raw_statistics_parquet',
#  'raw_tennis_power_parquet',
#  'raw_votes_parquet']

# %% [markdown]
# ## 1. Extracting Table Names using `os.listdir` and converting it to `set()` so we can have unique names

# %%
table_list = []
for folder in folders:
    files = os.listdir(BASE_DIR + folder)
    for file in files:
        name = file.split('.')[0]
        table_name = name.split('_')
        table_name = '_'.join(table_name[:-1])
        table_list.append(table_name)
        
table_set = set(table_list)
table_set
# Out:
# {'away_team',
#  'away_team_score',
#  'event',
#  'home_team',
#  'home_team_score',
#  'odds',
#  'pbp',
#  'power',
#  'round',
#  'season',
#  'statistics',
#  'time',
#  'tournament',
#  'venue',
#  'votes'}

# %% [markdown]
# ## 2. Creating a dictionary with keys for each table and appending table parquet files as a list for each key

# %%
table_dict = {name: [] for name in list(table_set)}
    
for folder in folders:
    files = os.listdir(BASE_DIR + folder)
    for file in files:
        table_name = file.split('.')[0].split('_')
        table_name = '_'.join(table_name[:-1])
        table_dict[table_name].append(BASE_DIR + folder + '/' + file)

# %% [markdown]
# ## 3. Reading each parquet file for each table and creating a dictionary for each dataframe with table names to concatenate them afterwards

# %%
dataframes_dict = {name: [] for name in list(table_set)}
for key in table_dict:
    for file in table_dict[key]:
        dataframes_dict[key].append(pd.read_parquet(file))

# %%
dataframes_dict['away_team']
# Out:
# [   match_id        name                    slug gender  user_count residence  \
#  0  11673958  Tirante T.  tirante-thiago-agustin      M        1519  La Plata
#
#              birthplace  height  weight         plays turned_pro  \
#  0  La Plata, Argentina    1.85      78  right-handed       None
#
#     current_prize  total_prize  player_id  current_rank name_code    country  \
#  0         249335       430793     221515           123       TIR  Argentina
#
#                   full_name
#  0  Tirante, Thiago Agustin  ,
#     match_id      name           slug gender  user_count residence birthplace  \
#  0  11673962  Heide G.  heide-gustavo      M        1177      None  Sao Paulo
#
#     height weight         plays turned_pro  current_prize  total_prize  \
#  0    1.88   None  right-handed       None          36929        87230
#
#     player_id  current_rank name_code country       full_name
#  0     302582           247       HEI  Brazil  Heide, Gustavo  ,
#     match_id              name                 slug gender  user_count  \
#  0  11673963  Jorda Sanchis D.  jorda-sanchis-david      M         344
#
#    residence        birthplace  height  weight         plays turned_pro  \
#  0     Spain  Barcelona, Spain    1.98      83  right-handed       None
#
#     current_prize  total_prize  player_id  current_rank name_code country  \
#  0          27028        72338      57155           331       JOR   Spain
#
#                full_name
#  0  Jorda Sanchis, David  ,
#     match_id             name                slug gender  user_count  \
#  0  11673993  Roca Batalla O.  roca-batalla-oriol      M         707
#
#                    residence birthplace  height  weight         plays  \
#  0  Santa Coloma de Gramenet  Barcelona    1.75      75  right-handed
#
#    turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
#  0       None          53418       317311      51100           213       ROC
#
#    country            full_name
#  0   Spain  Roca Batalla, Oriol  ,
#     match_id         name             slug gender  user_count        residence  \
#  0  11674000  Crawford O.  crawford-oliver      M         442  Spartanburg, SC
#
#               birthplace  height  weight         plays turned_pro  \
#  0  Spartanburg, SC, USA     1.8      84  right-handed       None
#
#     current_prize  total_prize  player_id  current_rank name_code country  \
#  0          40191       113045     213057           215       CRA     USA
#
#            full_name
#  0  Crawford, Oliver  ,
#     match_id         name           slug gender  user_count  \
#  0  11674008  Peniston R.  peniston-ryan      M        1325
#
#                    residence              birthplace  height  weight  \
#  0  Southend-on-sea, England  Southend-on-sea, Essex     1.8      75
#
#           plays turned_pro  current_prize  total_prize  player_id  \
#  0  left-handed       None         182028       509723      91240
#
#     current_rank name_code         country       full_name
#  0           179       PEN  United Kingdom  Peniston, Ryan  ,
#     match_id         name                slug gender  user_count residence  \
#  0  11674011  Shelbayh A.  shelbayh-abedallah      M        1411      None
#
#    birthplace  height weight plays turned_pro  current_prize  total_prize  \
#  0      Amman     1.8   None  None       None         104721       128500
#
#     player_id  current_rank name_code country            full_name
#  0     307383           187       SHE  Jordan  Shelbayh, Abedallah  ,
#     match_id       name          slug gender  user_count       residence  \
#  0  11674026  Machač T.  machac-tomas      M        2381  Czech republic
#
#                 birthplace  height  weight         plays turned_pro  \
#  0  Beroun, Czech Republic    1.83      73  right-handed       None
#
#     current_prize  total_prize  player_id  current_rank name_code  \
#  0         358816       873971     238300            78       MAC
#
#            country      full_name
#  0  Czech Republic  Machač, Tomáš  ,
#     match_id       name         slug gender  user_count residence  \
#  0  11674032  Draper J.  draper-jack      M        5892    London
#
#          birthplace  height  weight        plays turned_pro  current_prize  \
#  0  Sutton, England    1.93      75  left-handed       2018         614923
#
#     total_prize  player_id  current_rank name_code         country  \
#  0      1519143     258749            61       DRA  United Kingdom
#
#        full_name
#  0  Draper, Jack  ,
#     match_id           name             slug gender  user_count residence  \
#  0  11674034  Van Assche L.  van-assche-luca      M        3546      None
#
#            birthplace  height weight         plays turned_pro  current_prize  \
#  0  Woluwe St Lambert    1.78   None  right-handed       None         528705
#
#     total_prize  player_id  current_rank name_code country         full_name
#  0       662296     335102            90       VAN  France  Van Assche, Luca  ,
#     match_id       name            slug gender  user_count  \
#  0  11674074  Pegula J.  pegula-jessica      F       11721
#
#               residence        birthplace  height  weight         plays  \
#  0  Boca Raton, FL, USA  Buffalo, NY, USA     1.7      70  right-handed
#
#    turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
#  0       2012        4973242     10319372      44834             5       PEG
#
#    country        full_name
#  0     USA  Pegula, Jessica  ,
#     match_id       name              slug gender  user_count         residence  \
#  0  11674103  Bublik A.  bublik-alexander      M        7108  Gatchina, Russia
#
#           birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Gatchina, Russia    1.96      76  right-handed       2014        1308797
#
#     total_prize  player_id  current_rank name_code     country  \
#  0      4912703     163480            32       BUB  Kazakhstan
#
#             full_name
#  0  Bublik, Alexander  ,
#     match_id          name             slug gender  user_count residence  \
#  0  11674105  Međedović H.  mededovic-hamad      M        3889      None
#
#             birthplace  height weight         plays turned_pro  current_prize  \
#  0  Novi Pazar, Serbia    1.88   None  right-handed       None         279579
#
#     total_prize  player_id  current_rank name_code country         full_name
#  0       346548     321404           113       MED  Serbia  Međedović, Hamad  ,
#     match_id          name             slug gender  user_count residence  \
#  0  11674110  Međedović H.  mededovic-hamad      M        3889      None
#
#             birthplace  height weight         plays turned_pro  current_prize  \
#  0  Novi Pazar, Serbia    1.88   None  right-handed       None         279579
#
#     total_prize  player_id  current_rank name_code country         full_name
#  0       346548     321404           113       MED  Serbia  Međedović, Hamad  ,
#     match_id          name              slug gender  user_count  \
#  0  11674111  Mannarino A.  mannarino-adrian      M        5504
#
#           residence                      birthplace  height  weight  \
#  0  Valletta, Malta  Soisy-sous-Montmorency, France     1.8      79
#
#           plays turned_pro  current_prize  total_prize  player_id  \
#  0  left-handed       2004        1395263      9479850      15894
#
#     current_rank name_code country          full_name
#  0            22       MAN  France  Mannarino, Adrian  ,
#     match_id         name            slug gender  user_count        residence  \
#  0  11674112  Rodionov J.  rodionov-jurij      M        2382  Matzen, Austria
#
#             birthplace  height  weight        plays turned_pro  current_prize  \
#  0  Nuremberg, Germany    1.91      86  left-handed       2017         276484
#
#     total_prize  player_id  current_rank name_code  country        full_name
#  0       834004     200159           115       ROD  Austria  Rodionov, Jurij  ,
#     match_id      name             slug gender  user_count  \
#  0  11674113  Ofner S.  ofner-sebastian      M        3736
#
#                 residence                 birthplace  height  weight  \
#  0  Sankt Marein, Austria  Bruck an der Mur, Austria    1.91      81
#
#            plays turned_pro  current_prize  total_prize  player_id  \
#  0  right-handed       2014         670606      1465668      83397
#
#     current_rank name_code  country         full_name
#  0            43       OFN  Austria  Ofner, Sebastian  ,
#     match_id      name             slug gender  user_count           residence  \
#  0  11674114  Korda S.  korda-sebastian      M        7469  Bradenton, FL, USA
#
#             birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Bradenton, FL, USA    1.96      75  right-handed       None        1288192
#
#     total_prize  player_id  current_rank name_code country         full_name
#  0      3552528     195840            24       KOR     USA  Korda, Sebastian  ,
#     match_id         name             slug gender  user_count  \
#  0  11675440  Medvedev D.  medvedev-daniil      M       63350
#
#               residence      birthplace  height  weight         plays  \
#  0  Monte Carlo, Monaco  Moscow, Russia    1.98      83  right-handed
#
#    turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
#  0       2014        7699733     29866718     163504             3       MED
#
#    country         full_name
#  0  Russia  Medvedev, Daniil  ,
#     match_id      name           slug gender  user_count        residence  \
#  0  11675443  Jarry N.  jarry-nicolas      M        9517  Santiago, Chile
#
#          birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Santiago, Chile    1.98      90  right-handed       2014        1431219
#
#     total_prize  player_id  current_rank name_code country       full_name
#  0      3478135      89632            19       JAR   Chile  Jarry, Nicolas  ,
#     match_id        name             slug gender  user_count residence  \
#  0  11675444  Musetti L.  musetti-lorenzo      M       22366   Carrara
#
#         birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Carrara, Italy    1.85      75  right-handed       2019        1598590
#
#     total_prize  player_id  current_rank name_code country         full_name
#  0      3901074     261015            27       MUS   Italy  Musetti, Lorenzo  ,
#     match_id       name           slug gender  user_count            residence  \
#  0  11675445  Sinner J.  sinner-jannik      M       64879  Monte Carlo, Monaco
#
#             birthplace  height  weight         plays turned_pro  current_prize  \
#  0  San Candido, Italy    1.88      68  right-handed       2018        6915316
#
#     total_prize  player_id  current_rank name_code country       full_name
#  0     12447135     206570             4       SIN   Italy  Sinner, Jannik  ,
#     match_id         name             slug gender  user_count  \
#  0  11675446  Dimitrov G.  dimitrov-grigor      M       22646
#
#               residence         birthplace  height  weight         plays  \
#  0  Monte Carlo, Monaco  Haskovo, Bulgaria    1.91      81  right-handed
#
#    turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
#  0       2008        2252614     20583691      23581            14       DIM
#
#      country         full_name
#  0  Bulgaria  Dimitrov, Grigor  ,
#     match_id     name         slug gender  user_count     residence  \
#  0  11675447  Ruud C.  ruud-casper      M       29533  Oslo, Norway
#
#       birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Oslo, Norway    1.83      77  right-handed       2015        2601211
#
#     total_prize  player_id  current_rank name_code country     full_name
#  0     13500643     119248            11       RUU  Norway  Ruud, Casper  ,
#     match_id     name         slug gender  user_count     residence  \
#  0  11675448  Ruud C.  ruud-casper      M       29533  Oslo, Norway
#
#       birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Oslo, Norway    1.83      77  right-handed       2015        2601211
#
#     total_prize  player_id  current_rank name_code country     full_name
#  0     13500643     119248            11       RUU  Norway  Ruud, Casper  ,
#     match_id                  name                         slug gender  \
#  0  11675449  Davidovich Fokina A.  davidovich-fokina-alejandro      M
#
#     user_count   residence     birthplace  height  weight         plays  \
#  0        8793  Fuengirola  Malaga, Spain    1.83      80  right-handed
#
#    turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
#  0       2019        1509026      4476749     157456            26       DAV
#
#    country                     full_name
#  0   Spain  Davidovich Fokina, Alejandro  ,
#     match_id       name           slug gender  user_count            residence  \
#  0  11675450  Sinner J.  sinner-jannik      M       64879  Monte Carlo, Monaco
#
#             birthplace  height  weight         plays turned_pro  current_prize  \
#  0  San Candido, Italy    1.88      68  right-handed       2018        6915316
#
#     total_prize  player_id  current_rank name_code country       full_name
#  0     12447135     206570             4       SIN   Italy  Sinner, Jannik  ,
#     match_id        name           slug gender  user_count  \
#  0  11686269  Saville D.  saville-daria      F        1505
#
#                residence      birthplace  height  weight         plays  \
#  0  Melbourne, Australia  Moscow, Russia    1.66      61  right-handed
#
#    turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
#  0       2010         259375      4344200      40994           204       SAV
#
#       country       full_name
#  0  Australia  Saville, Daria  ,
#     match_id      name            slug gender  user_count            residence  \
#  0  11686272  Brady J.  brady-jennifer      F        1750  Boca Raton, FL, USA
#
#              birthplace  height  weight         plays turned_pro  \
#  0  Harrisburg, PA, USA    1.78      68  right-handed       2015
#
#     current_prize  total_prize  player_id  current_rank name_code country  \
#  0         322052      4192598      52273           230       BRA     USA
#
#           full_name
#  0  Brady, Jennifer  ,
#     match_id          name              slug gender  user_count     residence  \
#  0  11686275  Ostapenko J.  ostapenko-jelena      F        8314  Riga, Latvia
#
#       birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Riga, Latvia    1.77      68  right-handed       2012        1798842
#
#     total_prize  player_id  current_rank name_code country          full_name
#  0     11611607      64496            13       OST  Latvia  Ostapenko, Jelena  ,
#     match_id          name                slug gender  user_count residence  \
#  0  11686276  Samsonova L.  samsonova-liudmila      F        4833      None
#
#             birthplace  height weight         plays turned_pro  current_prize  \
#  0  Olenegorsk, Russia    1.82   None  right-handed       None        1873572
#
#     total_prize  player_id  current_rank name_code country            full_name
#  0      3646705     128584            16       SAM  Russia  Samsonova, Liudmila  ,
#     match_id        name             slug gender  user_count residence  \
#  0  11686281  Paolini J.  paolini-jasmine      F        5233      None
#
#                           birthplace  height weight         plays turned_pro  \
#  0  Castelnuovo di Garfagnana, Italy    1.63   None  right-handed       2012
#
#     current_prize  total_prize  player_id  current_rank name_code country  \
#  0         702123      2207834      69208            30       PAO   Italy
#
#            full_name
#  0  Paolini, Jasmine  ,
#     match_id      name          slug gender  user_count      residence  \
#  0  11688311  Smith K.  smith-keegan      M         330  San Diego, CA
#
#         birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Wilmington, NC    1.98      93  right-handed       None          14237
#
#     total_prize  player_id  current_rank name_code country      full_name
#  0        79745     232059           591       SMI     USA  Smith, Keegan  ,
#     match_id       name           slug gender  user_count residence birthplace  \
#  0  11696863  Glinka D.  glinka-daniil      M         250      None    Tallinn
#
#     height weight        plays turned_pro  current_prize  total_prize  \
#  0    1.88   None  left-handed       None          12265        34997
#
#     player_id  current_rank name_code  country       full_name
#  0     210033           499       GLI  Estonia  Glinka, Daniil  ,
#     match_id        name           slug gender  user_count       residence  \
#  0  11697105  Linette M.  linette-magda      F       10931  Poznan, Poland
#
#         birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Poznan, Poland    1.71      59  right-handed       2009        1538431
#
#     total_prize  player_id  current_rank name_code country       full_name
#  0      4998417      42289            24       LIN  Poland  Linette, Magda  ,
#     match_id      name         slug gender  user_count  \
#  0  11697107  Kenin S.  kenin-sofia      F        5194
#
#                   residence      birthplace  height  weight         plays  \
#  0  Pembroke Pines, FL, USA  Moscow, Russia     1.7      55  right-handed
#
#    turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
#  0       2017         709965      7435794      91960            33       KEN
#
#    country     full_name
#  0     USA  Kenin, Sofia  ,
#     match_id            name                 slug gender  user_count  \
#  0  11697108  Haddad Maia B.  haddad-maia-beatriz      F       15466
#
#                  residence         birthplace  height  weight        plays  \
#  0  Rio de Janeiro, Brazil  Sao Paulo, Brazil    1.85      78  left-handed
#
#    turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
#  0       2012        2382351      4452564      59702            11       HAD
#
#    country             full_name
#  0  Brazil  Haddad Maia, Beatriz  ,
#     match_id         name            slug gender  user_count residence  \
#  0  11697110  Rybakina E.  rybakina-elena      F       18975      None
#
#         birthplace  height weight         plays turned_pro  current_prize  \
#  0  Moscow, Russia    1.84   None  right-handed       2016        4577864
#
#     total_prize  player_id  current_rank name_code     country        full_name
#  0      9878663     186312             4       RYB  Kazakhstan  Rybakina, Elena  ,
#     match_id        name           slug gender  user_count residence  \
#  0  11697112  Nosková L.  noskova-linda      F        2930      None
#
#                 birthplace  height weight         plays turned_pro  \
#  0  Vsetin, Czech Republic    1.79   None  right-handed       None
#
#     current_prize  total_prize  player_id  current_rank name_code  \
#  0         551923       780924     274049            41       NOS
#
#            country       full_name
#  0  Czech Republic  Noskova, Linda  ,
#     match_id       name       slug gender  user_count residence  \
#  0  11697113  Wang Xiy.  wang-xiyu      F        2448      None
#
#                            birthplace  height weight        plays turned_pro  \
#  0  Taixing, Jiang Su Province, China    1.82   None  left-handed       2018
#
#     current_prize  total_prize  player_id  current_rank name_code country  \
#  0         570334      1370247     223148            69       WAN   China
#
#      full_name
#  0  Wang, Xiyu  ,
#     match_id          name                slug gender  user_count residence  \
#  0  11697117  Samsonova L.  samsonova-liudmila      F        4833      None
#
#             birthplace  height weight         plays turned_pro  current_prize  \
#  0  Olenegorsk, Russia    1.82   None  right-handed       None        1873572
#
#     total_prize  player_id  current_rank name_code country            full_name
#  0      3646705     128584            16       SAM  Russia  Samsonova, Liudmila  ,
#     match_id    name         slug gender  user_count                 residence  \
#  0  11697118  Rus A.  rus-arantxa      F        2413  Monster, The Netherlands
#
#                 birthplace  height  weight        plays turned_pro  \
#  0  Delft, The Netherlands     1.8      65  left-handed       2007
#
#     current_prize  total_prize  player_id  current_rank name_code      country  \
#  0         367086      2643194      19847            52       RUS  Netherlands
#
#        full_name
#  0  Rus, Arantxa  ,
#     match_id          name            slug gender  user_count       residence  \
#  0  11697119  Zvonareva V.  zvonareva-vera      F        1282  Moscow, Russia
#
#         birthplace  height weight         plays turned_pro  current_prize  \
#  0  Moscow, Russia    1.72   None  right-handed       2000         728874
#
#     total_prize  player_id  current_rank name_code country        full_name
#  0     13701594      18298           270       ZVO  Russia  Zvonareva, Vera  ,
#     match_id          name             slug gender  user_count  \
#  0  11697120  Kasatkina D.  kasatkina-daria      F        7463
#
#             residence         birthplace  height  weight         plays  \
#  0  Togliatty, Russia  Togliatty, Russia     1.7      62  right-handed
#
#    turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
#  0       2014        1415658      8977562     132370            18       KAS
#
#    country         full_name
#  0  Russia  Kasatkina, Daria  ,
#     match_id    name     slug gender  user_count       residence   birthplace  \
#  0  11697121  Zhu L.  zhu-lin      F        2718  Beijing, China  Wuxi, China
#
#     height  weight         plays turned_pro  current_prize  total_prize  \
#  0    1.73      64  right-handed       2012         901751      2458055
#
#     player_id  current_rank name_code country full_name
#  0      45584            37       ZHU   China  Zhu, Lin  ,
#     match_id      name        slug gender  user_count              residence  \
#  0  11697122  Gauff C.  gauff-cori      F       22431  Delray Beach, Fl. USA
#
#                birthplace  height weight         plays turned_pro  \
#  0  Delray Beach, Fl. USA    1.75   None  right-handed       2018
#
#     current_prize  total_prize  player_id  current_rank name_code country  \
#  0        5558018     10183094     264983             3       GAU     USA
#
#       full_name
#  0  Gauff, Cori  ,
#     match_id         name               slug gender  user_count residence  \
#  0  11697123  Kalinina A.  kalinina-anhelina      F        3565      None
#
#                 birthplace  height weight         plays turned_pro  \
#  0  Nova Kakhovka, Ukraine     1.8   None  right-handed       2013
#
#     current_prize  total_prize  player_id  current_rank name_code  country  \
#  0         956712      2481760      90664            27       KAL  Ukraine
#
#              full_name
#  0  Kalinina, Anhelina  ,
#     match_id          name                slug gender  user_count  \
#  0  11697124  Siniaková K.  siniakova-katerina      F        3533
#
#                          residence                      birthplace  height  \
#  0  Hradec Kralove, Czech Republic  Hradec Kralove, Czech Republic    1.74
#
#     weight         plays turned_pro  current_prize  total_prize  player_id  \
#  0      69  right-handed       2013        1003717      8679142      72376
#
#     current_rank name_code         country            full_name
#  0            45       SIN  Czech Republic  Siniakova, Katerina  ,
#     match_id        name         slug gender  user_count residence  \
#  0  11697126  Świątek I.  swiatek-iga      F       54206      None
#
#         birthplace  height weight         plays turned_pro  current_prize  \
#  0  Warsaw, Poland    1.76   None  right-handed       2016        8214738
#
#     total_prize  player_id  current_rank name_code country     full_name
#  0     20493969     228272             1       SWI  Poland  Swiatek, Iga  ,
#     match_id       name          slug gender  user_count residence birthplace  \
#  0  11697152  Sleeth L.  sleeth-layne      F         165      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None           8295        26563     213096
#
#     current_rank name_code country      full_name
#  0           743       SLE  Canada  Sleeth, Layne  ,
#     match_id        name            slug gender  user_count residence  \
#  0  11697216  Stewart H.  stewart-hamish      M         163      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None           9026        14328
#
#     player_id  current_rank name_code         country        full_name
#  0     245307           651       STE  United Kingdom  Stewart, Hamish  ,
#     match_id        name                     slug gender  user_count residence  \
#  0  11697223  Urrutia M.  urrutia-maria-florencia      F          48      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None           2505         3639
#
#     player_id  current_rank name_code    country                 full_name
#  0     207107           983       URR  Argentina  Urrutia, Maria Florencia  ,
#     match_id        name                     slug gender  user_count residence  \
#  0  11697237  Ambrogi L.  ambrogi-luciano-emanuel      M         303      None
#
#    birthplace  height weight plays turned_pro  current_prize  total_prize  \
#  0    Rosario    1.88   None  None       None          13916        23195
#
#     player_id  current_rank name_code    country                 full_name
#  0     333081           458       AMB  Argentina  Ambrogi, Luciano Emanuel  ,
#     match_id       name           slug gender  user_count residence birthplace  \
#  0  11697262  Sierra S.  sierra-solana      F        1081      None       None
#
#    height weight         plays turned_pro  current_prize  total_prize  \
#  0   None   None  right-handed       None          29884        50144
#
#     player_id  current_rank name_code    country       full_name
#  0     298913           182       SIE  Argentina  Sierra, Solana  ,
#     match_id       name                 slug gender  user_count residence  \
#  0  11697278  Angele J.  angele-jaimee-floyd      M         331    France
#
#    birthplace  height  weight         plays turned_pro  current_prize  \
#  0     Clichy    2.06      93  right-handed       None          11962
#
#     total_prize  player_id  current_rank name_code country  \
#  0        55364     206574           619       ANG  France
#
#                full_name
#  0  Angele, Jaimee Floyd  ,
#     match_id             name                 slug gender  user_count  \
#  0  11697304  Guillen Meza A.  guillen-meza-alvaro      M         433
#
#    residence birthplace  height weight plays turned_pro  current_prize  \
#  0      None  Guayaquil    1.75   None  None       None          22169
#
#     total_prize  player_id  current_rank name_code  country  \
#  0        38798     269909           312       GUI  Ecuador
#
#                full_name
#  0  Guillen Meza, Alvaro  ,
#     match_id      name        slug gender  user_count residence birthplace  \
#  0  11697306  Draxl L.  draxl-liam      M         584    Canada  Newmarket
#
#     height  weight         plays turned_pro  current_prize  total_prize  \
#  0    1.85      77  right-handed       None          27645        75988
#
#     player_id  current_rank name_code country    full_name
#  0     223513           302       DRA  Canada  Draxl, Liam  ,
#     match_id            name                slug gender  user_count residence  \
#  0  11697309  Janicijevic S.  janicijevic-selena      F         599      None
#
#                   birthplace  height weight         plays turned_pro  \
#  0  Nogent-sur-Marne, France    1.83   None  right-handed       None
#
#     current_prize  total_prize  player_id  current_rank name_code country  \
#  0         154490       319552     299619           287       JAN  France
#
#               full_name
#  0  Janicijevic, Selena  ,
#     match_id        name               slug gender  user_count residence  \
#  0  11697316  Kessler M.  kessler-mccartney      F         435      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None          65538        72258
#
#     player_id  current_rank name_code country           full_name
#  0     233214           224       KES     USA  Kessler, McCartney  ,
#     match_id        name            slug gender  user_count residence  \
#  0  11698042  Zarazúa R.  zarazua-renata      F        1266      None
#
#              birthplace  height weight         plays turned_pro  current_prize  \
#  0  Mexico City, Mexico     1.6   None  right-handed       2014          82995
#
#     total_prize  player_id  current_rank name_code country        full_name
#  0       526619     111189           105       ZAR  Mexico  Zarazúa, Renata  ,
#     match_id   name      slug gender  user_count residence birthplace height  \
#  0  11698055  Ma Y.  ma-yexin      F         443      None       None   None
#
#    weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None  None       None          34392        89793     190950
#
#     current_rank name_code country  full_name
#  0           218       YEX   China  Ma, Yexin  ,
#     match_id       name            slug gender  user_count residence  \
#  0  11698365  Poulos A.  poulos-annerly      F          71      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None              0         3186
#
#     player_id  current_rank name_code    country        full_name
#  0     244853          1335       POU  Australia  Poulos, Annerly  ,
#     match_id         name            slug gender  user_count residence  \
#  0  11698367  Marinkov P.  marinkov-pavle      M         102      None
#
#    birthplace  height weight plays turned_pro  current_prize  total_prize  \
#  0     Sydney    1.88   None  None       None           3047         4025
#
#     player_id  current_rank name_code    country        full_name
#  0     388080          1104       MAR  Australia  Marinkov, Pavle  ,
#     match_id            name             slug gender  user_count residence  \
#  0  11698377  Chikaraishi Y.  chikaraishi-yui      F          59      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None           1986        11853
#
#     player_id  current_rank name_code country         full_name
#  0     197532          1211       CHI   Japan  Chikaraishi, Yui  ,
#     match_id       name            slug gender  user_count     residence  \
#  0  11698379  Safwat M.  safwat-mohamed      M         747  Cairo, Egypt
#
#          birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Mansoura, Egypt     1.8      83  right-handed       2009          23083
#
#     total_prize  player_id  current_rank name_code country        full_name
#  0       735583      42029           358       SAF   Egypt  Safwat, Mohamed  ,
#     match_id        name           slug gender  user_count residence  \
#  0  11698395  Boulter K.  boulter-katie      F        2891      None
#
#             birthplace  height weight         plays turned_pro  current_prize  \
#  0  Leicester, England    1.82   None  right-handed       2013         489770
#
#     total_prize  player_id  current_rank name_code         country  \
#  0      1455524      62924            56       BOU  United Kingdom
#
#          full_name
#  0  Boulter, Katie  ,
#     match_id         name            slug gender  user_count residence  \
#  0  11698397  Andreeva M.  andreeva-mirra      F        6621      None
#
#    birthplace  height weight         plays turned_pro  current_prize  \
#  0       None    1.71   None  right-handed       None         625398
#
#     total_prize  player_id  current_rank name_code country        full_name
#  0       646907     406776            57       AND  Russia  Andreeva, Mirra  ,
#     match_id          name              slug gender  user_count     residence  \
#  0  11698398  Ostapenko J.  ostapenko-jelena      F        8314  Riga, Latvia
#
#       birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Riga, Latvia    1.77      68  right-handed       2012        1798842
#
#     total_prize  player_id  current_rank name_code country          full_name
#  0     11611607      64496            13       OST  Latvia  Ostapenko, Jelena  ,
#     match_id       name        slug gender  user_count       residence  \
#  0  11698399  Jabeur O.  jabeur-ons      F       29294  Tunis, Tunisia
#
#                  birthplace  height  weight         plays turned_pro  \
#  0  Ksar El Hellar, Tunisia    1.67      67  right-handed       2010
#
#     current_prize  total_prize  player_id  current_rank name_code  country  \
#  0        2662137     10316089      55401             6       JAB  Tunisia
#
#       full_name
#  0  Jabeur, Ons  ,
#     match_id           name              slug gender  user_count  \
#  0  11698400  Putintseva Y.  putintseva-yulia      F        2576
#
#          residence      birthplace  height  weight         plays turned_pro  \
#  0  Moscow, Russia  Moscow, Russia    1.63      59  right-handed       2010
#
#     current_prize  total_prize  player_id  current_rank name_code     country  \
#  0         608483      5754558      45545            66       PUT  Kazakhstan
#
#             full_name
#  0  Putintseva, Yulia  ,
#     match_id       name             slug gender  user_count     residence  \
#  0  11698401  Garcia C.  garcia-caroline      F       11006  Lyon, France
#
#                        birthplace  height  weight         plays turned_pro  \
#  0  Saint-Germain-en-Laye, France    1.77      61  right-handed       2011
#
#     current_prize  total_prize  player_id  current_rank name_code country  \
#  0        1555913     14109363      42339            20       GAR  France
#
#            full_name
#  0  Garcia, Caroline  ,
#     match_id        name            slug gender  user_count residence  \
#  0  11698402  Stearns P.  stearns-peyton      F        1425      None
#
#           birthplace  height weight         plays turned_pro  current_prize  \
#  0  Cincinnati, Ohio    1.73   None  right-handed       None         682638
#
#     total_prize  player_id  current_rank name_code country        full_name
#  0       840994     261095            49       STE     USA  Stearns, Peyton  ,
#     match_id        name              slug gender  user_count residence  \
#  0  11698403  Kužmova K.  kuzmova-katarina      F         334      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None          21168        48841
#
#     player_id  current_rank name_code   country          full_name
#  0     205282           517       KUZ  Slovakia  Kuzmova, Katarina  ,
#     match_id       name           slug gender  user_count residence birthplace  \
#  0  11698476  Gaubas V.  gaubas-vilius      M         491      None   Siauliai
#
#     height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0    1.78   None  None       None          20193        29334     322022
#
#     current_rank name_code    country       full_name
#  0           370       GAU  Lithuania  Gaubas, Vilius  ,
#     match_id         name            slug gender  user_count residence  \
#  0  11698477  Martynov D.  martynov-diana      F         172      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None           9583        22779
#
#     player_id  current_rank name_code country        full_name
#  0     288575           634       MAR  France  Martynov, Diana  ,
#     match_id      name           slug gender  user_count residence birthplace  \
#  0  11698544  Tabur C.  tabur-clement      M         566    Angers      REIMS
#
#     height  weight         plays turned_pro  current_prize  total_prize  \
#  0    1.73      70  right-handed       None          37471       119397
#
#     player_id  current_rank name_code country       full_name
#  0     206602           233       TAB  France  Tabur, Clement  ,
#     match_id        name            slug gender  user_count residence  \
#  0  11698550  Paulson A.  paulson-andrew      M         443      None
#
#    birthplace  height weight         plays turned_pro  current_prize  \
#  0     Prague    1.91   None  right-handed       None          25426
#
#     total_prize  player_id  current_rank name_code         country  \
#  0        96129     275467           316       PAU  Czech Republic
#
#           full_name
#  0  Paulson, Andrew  ,
#     match_id         name                    slug gender  user_count residence  \
#  0  11698683  Privara  P.  privara-peter-benjamin      M         169      None
#
#     birthplace  height weight plays turned_pro  current_prize  total_prize  \
#  0  Bratislava    1.88   None  None       None           9579        19305
#
#     player_id  current_rank name_code   country                 full_name
#  0     341952           725       PRI  Slovakia  Privara , Peter Benjamin  ,
#     match_id           name               slug gender  user_count residence  \
#  0  11698735  Bartunkova N.  bartunkova-nikola      F         668      None
#
#    birthplace height weight         plays turned_pro  current_prize  \
#  0       None   None   None  right-handed       None          21424
#
#     total_prize  player_id  current_rank name_code         country  \
#  0        60693     348987           294       BAR  Czech Republic
#
#              full_name
#  0  Bartunkova, Nikola  ,
#     match_id           name             slug gender  user_count residence  \
#  0  11698749  Gjorcheska L.  gjorcheska-lina      F         400      None
#
#    birthplace height weight         plays turned_pro  current_prize  \
#  0       None   None   None  right-handed       None          27822
#
#     total_prize  player_id  current_rank name_code          country  \
#  0       240998      67743           215       GJO  North Macedonia
#
#            full_name
#  0  Gjorcheska, Lina  ,
#     match_id           name               slug gender  user_count residence  \
#  0  11698757  Berberović N.  berberovic-nefisa      F         363      None
#
#                      birthplace height weight         plays turned_pro  \
#  0  Tuzla, Bosnia & Herzegovina   None   None  right-handed       None
#
#     current_prize  total_prize  player_id  current_rank name_code  \
#  0          17279        84670     194356           362       BER
#
#                  country           full_name
#  0  Bosnia & Herzegovina  Berberovic, Nefisa  ,
#     match_id       name           slug gender  user_count residence birthplace  \
#  0  11698861  Glinka D.  glinka-daniil      M         250      None    Tallinn
#
#     height weight        plays turned_pro  current_prize  total_prize  \
#  0    1.88   None  left-handed       None          12265        34997
#
#     player_id  current_rank name_code  country       full_name
#  0     210033           499       GLI  Estonia  Glinka, Daniil  ,
#     match_id          name            slug gender  user_count residence  \
#  0  11698931  Loccisano M.  loccisano-mike      M          34      None
#
#    birthplace height weight plays turned_pro current_prize  total_prize  \
#  0       None   None   None  None       None          None         3628
#
#     player_id  current_rank name_code  country        full_name
#  0     205807          1800       LOC  Germany  Loccisano, Mike  ,
#     match_id       name              slug gender  user_count residence  \
#  0  11698932  Liucci F.  liucci-francesco      M          76      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None              0         2828
#
#     player_id  current_rank name_code country          full_name
#  0     245105          1495       LIU   Italy  Liucci, Francesco  ,
#     match_id       name            slug gender  user_count residence  \
#  0  11698933  Caruso A.  caruso-antonio      M         125      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None           1840         2662
#
#     player_id  current_rank name_code country        full_name
#  0     327786          1254       CAR   Italy  Caruso, Antonio  ,
#     match_id      name       slug gender  user_count residence birthplace  \
#  0  11698943  Heger T.  heger-tim      M          67      None  Östringen
#
#     height weight         plays turned_pro  current_prize  total_prize  \
#  0    1.85   None  right-handed       None           1395        11790
#
#     player_id  current_rank name_code  country   full_name
#  0     188965          1438       HEG  Germany  Heger, Tim  ,
#     match_id       name         slug gender  user_count         residence  \
#  0  11698944  Martin T.  martin-toby      M         139  Chesham, England
#
#                birthplace  height  weight         plays turned_pro  \
#  0  High Wycombe, England    1.88      78  right-handed       None
#
#     current_prize  total_prize  player_id  current_rank name_code  \
#  0           2788        58378      58219          1157       MAR
#
#            country     full_name
#  0  United Kingdom  Martin, Toby  ,
#     match_id           name              slug gender  user_count residence  \
#  0  11698966  El Sallaly A.  el-sallaly-akram      M          58      None
#
#    birthplace height weight plays turned_pro current_prize  total_prize  \
#  0       None   None   None  None       None          None         7775
#
#     player_id current_rank name_code country          full_name
#  0      93809         None        EL   Egypt  El Sallaly, Akram  ,
#     match_id        name          slug gender  user_count residence birthplace  \
#  0  11698968  Murgett F.  murgett-finn      M          62      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None           1482         4518     275949
#
#     current_rank name_code         country      full_name
#  0          1438       MUR  United Kingdom  Murgett, Finn  ,
#     match_id       name             slug gender  user_count residence  \
#  0  11698974  Mossur M.  mossur-mykhailo      M          45      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None            670         1390
#
#     player_id  current_rank name_code  country         full_name
#  0     383428          1717       MOS  Ukraine  Mossur, Mykhailo  ,
#     match_id     name         slug gender  user_count residence birthplace  \
#  0  11698979  Sada I.  sada-iacopo      M          70      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None            582         1687     301989
#
#     current_rank name_code country     full_name
#  0          1390       SAD   Italy  Sada, Iacopo  ,
#     match_id      name         slug gender  user_count residence birthplace  \
#  0  11698986  Dimic M.  dimic-matic      M          62      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None           2642         6027     294381
#
#     current_rank name_code   country     full_name
#  0          1359       DIM  Slovenia  Dimic, Matic  ,
#     match_id         name              slug gender  user_count residence  \
#  0  11698987  Michalik R.  michalik-radovan      M          44      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None           1745         4063
#
#     player_id  current_rank name_code   country          full_name
#  0     371080          1470       MIC  Slovakia  Michalik, Radovan  ,
#     match_id         name             slug gender  user_count residence  \
#  0  11698990  Sandberg V.  sandberg-vivien      F          75      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None            710         2038
#
#     player_id current_rank name_code  country         full_name
#  0     204380         None       SAN  Germany  Sandberg, Vivien  ,
#     match_id         name            slug gender  user_count residence  \
#  0  11698991  Simundza J.  simundza-josip      M          93      None
#
#    birthplace  height weight plays turned_pro  current_prize  total_prize  \
#  0      Split    1.96   None  None       None           1793         3686
#
#     player_id  current_rank name_code  country        full_name
#  0     380568          1438       SIM  Croatia  Simundza, Josip  ,
#     match_id      name       slug gender  user_count           residence  \
#  0  11698995  Panák Y.  panak-yvo      M          36  Ernsgaden, Germany
#
#             birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Stuttgart, Germany    1.85      78  right-handed       None            130
#
#     total_prize  player_id  current_rank name_code         country   full_name
#  0         8006     100087          1439       PAN  Czech Republic  Panák, Yvo  ,
#     match_id            name                slug gender  user_count residence  \
#  0  11698998  Malgiaritta M.  malgiaritta-maurus      M          86      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None           1668         2935
#
#     player_id  current_rank name_code      country            full_name
#  0     302531          1454       MAL  Switzerland  Malgiaritta, Maurus  ,
#     match_id       name           slug gender  user_count residence birthplace  \
#  0  11699000  Puskar S.  puskar-samuel      M          63      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None           2060         7720     256797
#
#     current_rank name_code   country       full_name
#  0          1162       PUS  Slovakia  Puskar, Samuel  ,
#     match_id            name               slug gender  user_count residence  \
#  0  11699002  Podorozhnyi A.  podorozhnyi-artem      M          50      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None            217          792
#
#     player_id  current_rank name_code  country           full_name
#  0     383066          1428       POD  Ukraine  Podorozhnyi, Artem  ,
#     match_id        name                    slug gender  user_count residence  \
#  0  11699008  Kargina V.  kargina-valerija-maija      F          66      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None           1288         2064
#
#     player_id  current_rank name_code country                full_name
#  0     455810          1214       KAR  Latvia  Kargina, Valerija Maija  ,
#     match_id          name               slug gender  user_count residence  \
#  0  11699011  Vatteroni L.  vatteroni-lorenzo      M         114      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None              0         4287
#
#     player_id  current_rank name_code country           full_name
# ...
#     match_id      name           slug gender  user_count residence birthplace  \
#  0  11701745  Bossi C.  bossi-camilla      F          96      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None           2138         3081     280925
#
#     current_rank name_code country       full_name
#  0          1269       BOS  Brazil  Bossi, Camilla  ,
#     match_id           name                slug gender  user_count residence  \
#  0  11701748  Villoslada E.  villoslada-edouard      M          86      None
#
#    birthplace  height weight plays turned_pro  current_prize  total_prize  \
#  0     Sèvres     1.8   None  None       None           1513         6537
#
#     player_id  current_rank name_code country            full_name
#  0     372740          1473       VIL  France  Villoslada, Edouard  ,
#     match_id         name            slug gender  user_count  \
#  0  11701749  Sakamoto P.  sakamoto-pedro      M         643
#
#                  residence         birthplace  height  weight         plays  \
#  0  Rio de Janeiro, Brazil  Guarulhos, Brazil    1.78      78  right-handed
#
#    turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
#  0       None          21647       158106      65576           339       SAK
#
#    country        full_name
#  0  Brazil  Sakamoto, Pedro  ,
#     match_id        name          slug gender  user_count  \
#  0  11701752  Pereira J.  pereira-jose      M         368
#
#                   residence                  birthplace  height  weight  \
#  0  Curitiba-Parana, Brazil  Santana do Ipanema, Brazil     1.8      74
#
#            plays turned_pro  current_prize  total_prize  player_id  \
#  0  right-handed       None          11021       165781      16564
#
#     current_rank name_code country      full_name
#  0           569       PER  Brazil  Pereira, Jose  ,
#     match_id        name                slug gender  user_count residence  \
#  0  11701761  Trotter J.  trotter-james-kent      M         328     Japan
#
#      birthplace  height  weight         plays turned_pro  current_prize  \
#  0  Nishinomiya    1.83      75  right-handed       None          14838
#
#     total_prize  player_id  current_rank name_code country            full_name
#  0        32183     255993           461       TRO   Japan  Trotter, James Kent  ,
#     match_id       name              slug gender  user_count residence  \
#  0  11701779  Wagner S.  wagner-stephanie      F         281      None
#
#    birthplace height weight         plays turned_pro  current_prize  \
#  0       None   None   None  right-handed       None           6861
#
#     total_prize  player_id  current_rank name_code  country          full_name
#  0        90023      74875           560       WAG  Germany  Wagner, Stephanie  ,
#     match_id           name              slug gender  user_count residence  \
#  0  11701780  Iamachkine P.  iamachkine-pedro      M          82      None
#
#    birthplace  height weight plays turned_pro  current_prize  total_prize  \
#  0       Lima     1.8   None  None       None            929         8048
#
#     player_id  current_rank name_code country          full_name
#  0     224590          1408       IAM    Peru  Iamachkine, Pedro  ,
#     match_id       name            slug gender  user_count residence  \
#  0  11701781  Zusman R.  zusman-richard      M          48      None
#
#    birthplace  height weight plays turned_pro  current_prize  total_prize  \
#  0   New York    1.73   None  None       None           1843         6725
#
#     player_id  current_rank name_code country        full_name
#  0     253327          1473       ZUS     USA  Zusman, Richard  ,
#     match_id     name       slug gender  user_count residence birthplace  \
#  0  11701782  Zaar L.  zaar-lisa      F         242      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None           8179        19688     152106
#
#     current_rank name_code country   full_name
#  0           740       ZAA  Sweden  Zaar, Lisa  ,
#     match_id        name            slug gender  user_count residence  \
#  0  11701783  Brosset S.  brosset-samuel      M         142      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None            130         8657
#
#     player_id  current_rank name_code country        full_name
#  0     256796          1498       SAM  France  Brosset, Samuel  ,
#     match_id           name              slug gender  user_count residence  \
#  0  11701785  Lopatetska D.  lopatetska-daria      F         427      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None           5405        74063
#
#     player_id  current_rank name_code  country          full_name
#  0     276713           863       LOD  Ukraine  Lopatetska, Daria  ,
#     match_id         name            slug gender  user_count residence  \
#  0  11701788  Battesti A.  battesti-alice      F          49      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None           1483         2511
#
#     player_id  current_rank name_code country        full_name
#  0     313823          1363       BAT  France  Battesti, Alice  ,
#     match_id      name            slug gender  user_count residence birthplace  \
#  0  11701839  Rocha H.  rocha-henrique      M         845      None      Porto
#
#     height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0     1.8   None  None       None          40193        57607     341820
#
#     current_rank name_code   country        full_name
#  0           246       ROC  Portugal  Rocha, Henrique  ,
#     match_id        name          slug gender  user_count residence birthplace  \
#  0  11701840  Bertola R.  bertola-remy      M         489      None     Lugano
#
#     height weight         plays turned_pro  current_prize  total_prize  \
#  0    1.75   None  right-handed       None          26744        78009
#
#     player_id  current_rank name_code      country      full_name
#  0     145108           394       BER  Switzerland  Bertola, Remy  ,
#     match_id      name         slug gender  user_count residence birthplace  \
#  0  11701842  Hance K.  hance-kimmi      F          69      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None           4698        11339     275109
#
#     current_rank name_code country     full_name
#  0           806       HAN     USA  Hance, Kimmi  ,
#     match_id     name         slug gender  user_count residence birthplace  \
#  0  11701843  Kolb N.  kolb-nadiya      F         131      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None          12091        49378      46650
#
#     current_rank name_code  country     full_name
#  0           614       KOL  Ukraine  Kolb, Nadiya  ,
#     match_id           name              slug gender  user_count residence  \
#  0  11701919  El Sallaly A.  el-sallaly-akram      M          58      None
#
#    birthplace height weight plays turned_pro current_prize  total_prize  \
#  0       None   None   None  None       None          None         7775
#
#     player_id current_rank name_code country          full_name
#  0      93809         None        EL   Egypt  El Sallaly, Akram  ,
#     match_id         name            slug gender  user_count residence  \
#  0  11701920  Kukasian A.  kukasian-artur      M          39      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None           1100         1410
#
#     player_id  current_rank name_code country        full_name
#  0     382361          1428       KUK  Russia  Kukasian, Artur  ,
#     match_id           name                 slug gender  user_count  \
#  0  11701923  Uzhylovsky V.  uzhylovsky-vladimir      M          83
#
#         residence  birthplace  height  weight         plays turned_pro  \
#  0  Kiev, Ukraine  Krivoy Rog    1.96     102  right-handed       2005
#
#     current_prize  total_prize  player_id  current_rank name_code  country  \
#  0              0        85971      16852          1341       UZV  Ukraine
#
#                full_name
#  0  Uzhylovsky, Vladimir  ,
#     match_id     name         slug gender  user_count residence birthplace  \
#  0  11701925  Sada I.  sada-iacopo      M          70      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None            582         1687     301989
#
#     current_rank name_code country     full_name
#  0          1390       SAD   Italy  Sada, Iacopo  ,
#     match_id        name          slug gender  user_count residence birthplace  \
#  0  11701932  Murgett F.  murgett-finn      M          62      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None           1482         4518     275949
#
#     current_rank name_code         country      full_name
#  0          1438       MUR  United Kingdom  Murgett, Finn  ,
#     match_id            name               slug gender  user_count  \
#  0  11702042  de Schepper K.  de-schepper-kenny      M         510
#
#            residence        birthplace  height  weight        plays turned_pro  \
#  0  Toulouse, France  Bordeaux, France    2.03      98  left-handed       2010
#
#     current_prize  total_prize  player_id  current_rank name_code country  \
#  0          15825      1406183      41473           476       DES  France
#
#              full_name
#  0  de Schepper, Kenny  ,
#     match_id      name           slug gender  user_count  \
#  0  11702214  Bruna E.  bruna-esteban      M         128
#
#                   residence      birthplace  height  weight        plays  \
#  0  Buenos Aires, Argentina  Iquique, Chile    1.83      80  left-handed
#
#    turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
#  0       None            130        15693     113983          1409       BRU
#
#    country       full_name
#  0   Chile  Bruna, Esteban  ,
#     match_id          name               slug gender  user_count residence  \
#  0  11702217  Gagliardo L.  gagliardo-lorenzo      M         119      None
#
#    birthplace  height weight         plays turned_pro  current_prize  \
#  0      Pilar    1.75   None  right-handed       None           1304
#
#     total_prize  player_id  current_rank name_code country           full_name
#  0        13274     255413          1415       GAG   Italy  Gagliardo, Lorenzo  ,
#     match_id         name               slug gender  user_count residence  \
#  0  11702218  Oliveira C.  oliveira-cristian      M          77      None
#
#    birthplace height weight plays turned_pro  current_prize  total_prize  \
#  0       None   None   None  None       None              0         8248
#
#     player_id  current_rank name_code country           full_name
#  0     260129          1555       OLI  Brazil  Oliveira, Cristian  ,
#     match_id         name               slug gender  user_count residence  \
#  0  11702220  Vilicich B.  vilicich-bautista      M         117      None
#
#    birthplace  height weight plays turned_pro  current_prize  total_prize  \
#  0   Balcarce     1.8   None  None       None           2255         6031
#
#     player_id  current_rank name_code    country           full_name
#  0     329533          1163       VIL  Argentina  Vilicich, Bautista  ,
#     match_id                name                     slug gender  user_count  \
#  0  11702221  Dedura-Palomero M.  dedura-palomero-mariano      M          58
#
#    residence birthplace height weight plays turned_pro  current_prize  \
#  0      None       None   None   None  None       None            927
#
#     total_prize  player_id  current_rank name_code  country  \
#  0         1017     460789          1403       DED  Germany
#
#                    full_name
#  0  Dedura-Palomero, Mariano  ,
#     match_id                name                     slug gender  user_count  \
#  0  11702232  Aguilar Cardozo J.  aguilar-cardozo-joaquin      M         136
#
#    residence birthplace height weight plays turned_pro  current_prize  \
#  0      None       None   None   None  None       None           2698
#
#     total_prize  player_id  current_rank name_code  country  \
#  0         3558     452586          1098       AGU  Uruguay
#
#                    full_name
#  0  Aguilar Cardozo, Joaquin  ,
#     match_id       name           slug gender  user_count residence birthplace  \
#  0  11702238  Derdoy F.  derdoy-felipe      M          51      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None            430         4458     146030
#
#     current_rank name_code    country       full_name
#  0          1489       DER  Argentina  Derdoy, Felipe  ,
#     match_id                 name                     slug gender  user_count  \
#  0  11702243  Mouilleron Salvo M.  mouilleron-salvo-manuel      M         100
#
#    residence birthplace  height weight plays turned_pro  current_prize  \
#  0      None     Tandil    1.91   None  None       None           1236
#
#     total_prize  player_id  current_rank name_code    country  \
#  0         3091     322053          1314       MOU  Argentina
#
#                    full_name
#  0  Mouilleron Salvo, Manuel  ,
#     match_id        name              slug gender  user_count residence  \
#  0  11702244  Simonit E.  simonit-ezequiel      M          89      None
#
#    birthplace  height weight plays turned_pro  current_prize  total_prize  \
#  0     PARANA    1.75   None  None       None           1000         5188
#
#     player_id  current_rank name_code    country          full_name
#  0     329576          1430       SIM  Argentina  Simonit, Ezequiel  ,
#     match_id     name            slug gender  user_count residence birthplace  \
#  0  11702248  Noel M.  noel-mallaurie      F         152      None       None
#
#    height weight         plays turned_pro  current_prize  total_prize  \
#  0   None   None  right-handed       None           1974        45447
#
#     player_id  current_rank name_code country        full_name
#  0     108701           985       NOE  France  Noel, Mallaurie  ,
#     match_id       name        slug gender  user_count residence birthplace  \
#  0  11703443  Kalina V.  kalina-vit      M          41      None       None
#
#    height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0   None   None  None       None           1464         1859     416491
#
#     current_rank name_code         country    full_name
#  0          1454       KAL  Czech Republic  Kalina, Vit  ,
#     match_id    name       slug gender  user_count residence birthplace  \
#  0  11703445  Nad P.  nad-peter      M          73      None     Prague
#
#     height weight plays turned_pro  current_prize  total_prize  player_id  \
#  0    1.91   None  None       None           1938         6967     349490
#
#     current_rank name_code   country   full_name
#  0          1473       NAD  Slovakia  Nad, Peter  ,
#     match_id         name              slug gender  user_count residence  \
#  0  11703470  Lizarazo Y.  lizarazo-yuliana      F         248      None
#
#           birthplace  height weight         plays turned_pro  current_prize  \
#  0  Cúcuta, Colombia    1.75   None  right-handed       None          22869
#
#     total_prize  player_id  current_rank name_code   country          full_name
#  0       119050      42864           837       LIZ  Colombia  Lizarazo, Yuliana  ]

# %% [markdown]
# ## 4. Concatenating each dataframe value and creating a dataframe with relevant name for the table and saving the dataframe as a csv file to be able to use later and share with the team

# %%
output_dir = 'tennis_csv/'
for key in dataframes_dict:
    dataframe_name = f'df_{key}'
    df = globals()[dataframe_name] = pd.concat(dataframes_dict[key], ignore_index=True)
    csv_file_name = f"{dataframe_name}.csv"
    file_path = os.path.join(output_dir, csv_file_name)
    df.to_csv(file_path, index=False)
# Out:
# C:\Users\arian\AppData\Local\Temp\ipykernel_22300\1441828325.py:4: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = globals()[dataframe_name] = pd.concat(dataframes_dict[key], ignore_index=True)

# %% [markdown]
# # Loading Data
#
# ***STEPS***
# 1. Loading all the dataframes from csv file
#
# 2. Cleaning Dataframes and Understanding what they present

# %%
INPUT_DIR = 'tennis_csv/'

# %% [markdown]
# ## 1. Loading all the dataframes from csv file

# %%
for file in os.listdir(INPUT_DIR):
    df_name = file.split('.')[0] + '_csv'
    globals()[df_name] = pd.read_csv(INPUT_DIR + file)

# %% [markdown]
# ### 1. MatchTournamentInfo
#
# 1. `match_id`
#     * **Numerical**
#     * Showing ID of the match and seems like all the tables relate to each other with this ID
#
# 2. `tournament_id`
#     * **Numerical**
#     * Showing ID of the tournament for each match.
#     * Has duplicate values that differ with match ID
#
# 3. `tournament_name`
#     * **Categorical**
#     * This column shows tournament name and it is combination of city and country shown like this : `City, Country`
#     * This column has **55 Unique Values**
# 4. `tournament_slug`
#     * **Categorical**
#     * This column shows tournament name and it is combination of city and country shown like this : `city-country`
#     * This column has **55 Unique Values**
#
# 5. `tournament_unique_id`
#     * **Numerical**
#     * All the values of this column is missing and **This column will be droped in the Cleaning Process**
# 6. `tournament_category_name`
#     * **Categorical**
#     * This column shows the category of the tournament
#     * Has **5 Unique Values**
#         * Challenger
#         * WTA
#         * ATP
#         * ITF Men
#         * ITF Women
#
# 7. `tournament_category_slug`
#     * **Categorical**
#     * This column shows the category of the tournament in slug meaning they are lower case and have no space
#     * Has **5 Unique Values**
#         * challenger
#         * wta
#         * atp
#         * itf-men
#         * itf-women
#
# 8. `user_count`
#     * **Numerical**
#     * This column shows how many users participated in the tournament
#     * Some of the information about this column:
#         * Mean : 223.56
#         * Min : 2
#         * Max : 3627
#         * std : 711.36
#         * Q1 : 7
#         * Q3 : 19
#
#
# 9. `ground_type`
#     * **Categorical**
#     * This column shows what kind of ground the match was played on
#     * Has **6 Unique Values**
#         * Red clay
#         * Hardcourt outdoor
#         * Hardcourt indoor
#         * Carpet indoor
#         * nan
#         * Synthetic outdoor
#     * **Has 17 Missing Values that will be dropped**
#
#
# 10. `tennis_points`
#     * **Numerical**
#     * This column shows how many points were scored in this tournament
#     * This column has **600 Missing Values** - *Not decided what to do with it*
#     * Some of the information about this column:
#         * Mean : 406.097561
#         * Min : 75
#         * Max : 1000
#         * std : 412.441871
#         * Q1 : 100
#         * Q3 : 1000
#
# ***All the following columns only have **One** Value and **None** is Missing***
#
# 11. `has_event_player_statistics`
#
# 12. `crowd_sourcing_enabled`
#
# 13. `has_performance_graph_feature`
#
# 14. `display_inverse_home_away_teams`
#
# 15. `priority`
#
# 16. `competition_type`

# %%
df_tournament_csv.ground_type.unique()
# Out:
# array(['Red clay', 'Hardcourt outdoor', 'Hardcourt indoor',
#        'Carpet indoor', nan, 'Synthetic outdoor'], dtype=object)

# %%
df_tournament_csv.head()
# Out:
#    match_id  tournament_id   tournament_name  tournament_slug  \
# 0  11673958         121441  Bogota, Colombia  bogota-colombia
# 1  11673962         121441  Bogota, Colombia  bogota-colombia
# 2  11673963         121441  Bogota, Colombia  bogota-colombia
# 3  11673993         121451   Braga, Portugal   braga-portugal
# 4  11674000         121453   Charleston, USA   charleston-usa
#
#    tournament_unique_id tournament_category_name tournament_category_slug  \
# 0                   NaN               Challenger               challenger
# 1                   NaN               Challenger               challenger
# 2                   NaN               Challenger               challenger
# 3                   NaN               Challenger               challenger
# 4                   NaN               Challenger               challenger
#
#    user_count        ground_type  tennis_points  has_event_player_statistics  \
# 0         125           Red clay          125.0                        False
# 1         125           Red clay          125.0                        False
# 2         125           Red clay          125.0                        False
# 3         163           Red clay           75.0                        False
# 4          71  Hardcourt outdoor           75.0                        False
#
#    crowd_sourcing_enabled  has_performance_graph_feature  \
# 0                   False                          False
# 1                   False                          False
# 2                   False                          False
# 3                   False                          False
# 4                   False                          False
#
#    display_inverse_home_away_teams  priority  competition_type
# 0                            False         0                 2
# 1                            False         0                 2
# 2                            False         0                 2
# 3                            False         0                 2
# 4                            False         0                 2

# %%
df_home_team.head()
# Out:
#    match_id             name                    slug gender  user_count  \
# 0  11673958  Barrios Vera T.      barrios-vera-tomas      M        2915
# 1  11673962       Tirante T.  tirante-thiago-agustin      M        1519
# 2  11673963         Heide G.           heide-gustavo      M        1177
# 3  11673993     Ajduković D.          ajdukovic-duje      M        1293
# 4  11674000      Escobedo E.        escobedo-ernesto      M         680
#
#               residence            birthplace  height weight         plays  \
# 0              Santiago        Chillan, Chile    1.91     83  right-handed
# 1              La Plata   La Plata, Argentina    1.85     78  right-handed
# 2                  None             Sao Paulo    1.88   None  right-handed
# 3       Zagreb, Croatia        Split, Croatia    1.88     75  right-handed
# 4  West Covina, CA, USA  Los Angeles, CA, USA    1.85     82  right-handed
#
#   turned_pro current_prize total_prize  player_id current_rank name_code  \
# 0       2014        265608      646273     132834          103       BAR
# 1       None        249335      430793     221515          123       TIR
# 2       None         36929       87230     302582          247       HEI
# 3       None         63678      198866     207081          143       AJD
# 4       2014         84375     1280430      80491          404       ESC
#
#      country                full_name
# 0      Chile      Barrios Vera, Tomás
# 1  Argentina  Tirante, Thiago Agustin
# 2     Brazil           Heide, Gustavo
# 3    Croatia          Ajduković, Duje
# 4     Mexico        Escobedo, Ernesto

# %%
df_event.head()
# Out:
#    match_id first_to_serve home_team_seed away_team_seed  custom_id  \
# 0  11673958           None              1              4  JgdbspFNb
# 1  11673962           None              4           None  pFNbsHbwc
# 2  11673963           None           None           None   fTxsHbwc
# 3  11673993           None           None              Q   axvsGQHb
# 4  11674000           None              Q             WC   QjHshlKb
#
#   winner_code  default_period_count  start_datetime              match_slug  \
# 0           2                     3      1696094700    tirante-barrios-vera
# 1           1                     3      1696176000           heide-tirante
# 2           1                     3      1696087800     heide-jorda-sanchis
# 3           2                     3      1696154400  ajdukovic-roca-batalla
# 4           2                     3      1696086000       crawford-escobedo
#
#    final_result_only
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False

# %%
df_tournament[df_tournament['tournament_id'] == 121453]
# Out:
#    match_id  tournament_id  tournament_name tournament_slug  \
# 4  11674000         121453  Charleston, USA  charleston-usa
# 5  11674008         121453  Charleston, USA  charleston-usa
# 6  11674011         121453  Charleston, USA  charleston-usa
#
#   tournament_unique_id tournament_category_name tournament_category_slug  \
# 4                 None               Challenger               challenger
# 5                 None               Challenger               challenger
# 6                 None               Challenger               challenger
#
#    user_count        ground_type tennis_points  has_event_player_statistics  \
# 4          71  Hardcourt outdoor            75                        False
# 5          71  Hardcourt outdoor            75                        False
# 6          71  Hardcourt outdoor            75                        False
#
#    crowd_sourcing_enabled  has_performance_graph_feature  \
# 4                   False                          False
# 5                   False                          False
# 6                   False                          False
#
#    display_inverse_home_away_teams  priority  competition_type
# 4                            False         0                 2
# 5                            False         0                 2
# 6                            False         0                 2

# %%
df_tournament_csv.columns
# Out:
# Index(['match_id', 'tournament_id', 'tournament_name', 'tournament_slug',
#        'tournament_unique_id', 'tournament_category_name',
#        'tournament_category_slug', 'user_count', 'ground_type',
#        'tennis_points', 'has_event_player_statistics',
#        'crowd_sourcing_enabled', 'has_performance_graph_feature',
#        'display_inverse_home_away_teams', 'priority', 'competition_type'],
#       dtype='object')

# %%
df_tournament_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   match_id                         764 non-null    int64
#  1   tournament_id                    764 non-null    int64
#  2   tournament_name                  764 non-null    object
#  3   tournament_slug                  764 non-null    object
#  4   tournament_unique_id             0 non-null      float64
#  5   tournament_category_name         764 non-null    object
#  6   tournament_category_slug         764 non-null    object
#  7   user_count                       764 non-null    int64
#  8   ground_type                      747 non-null    object
#  9   tennis_points                    164 non-null    float64
#  10  has_event_player_statistics      764 non-null    bool
#  11  crowd_sourcing_enabled           764 non-null    bool
#  12  has_performance_graph_feature    764 non-null    bool
#  13  display_inverse_home_away_teams  764 non-null    bool
#  14  priority                         764 non-null    int64
#  15  competition_type                 764 non-null    int64
# dtypes: bool(4), float64(2), int64(5), object(5)
# memory usage: 74.7+ KB

# %%
df_tournament_csv.describe()
# Out:
#            match_id  tournament_id  tournament_unique_id   user_count  \
# count  7.640000e+02     764.000000                   0.0   764.000000
# mean   1.169902e+07  121710.625654                   NaN   223.560209
# std    5.029278e+03     538.709546                   NaN   711.361346
# min    1.167396e+07  119387.000000                   NaN     2.000000
# 25%    1.169901e+07  121843.000000                   NaN     7.000000
# 50%    1.169935e+07  121856.000000                   NaN    11.000000
# 75%    1.170151e+07  121870.000000                   NaN    19.000000
# max    1.170352e+07  121898.000000                   NaN  3627.000000
#
#        tennis_points  priority  competition_type
# count     164.000000     764.0             764.0
# mean      406.097561       0.0               2.0
# std       412.441871       0.0               0.0
# min        75.000000       0.0               2.0
# 25%       100.000000       0.0               2.0
# 50%       100.000000       0.0               2.0
# 75%      1000.000000       0.0               2.0
# max      1000.000000       0.0               2.0

# %%
df_tournament_csv.isna().sum()
# Out:
# match_id                             0
# tournament_id                        0
# tournament_name                      0
# tournament_slug                      0
# tournament_unique_id               764
# tournament_category_name             0
# tournament_category_slug             0
# user_count                           0
# ground_type                         17
# tennis_points                      600
# has_event_player_statistics          0
# crowd_sourcing_enabled               0
# has_performance_graph_feature        0
# display_inverse_home_away_teams      0
# priority                             0
# competition_type                     0
# dtype: int64

# %%
df_tournament_csv.nunique()
# Out:
# match_id                           764
# tournament_id                       56
# tournament_name                     55
# tournament_slug                     55
# tournament_unique_id                 0
# tournament_category_name             5
# tournament_category_slug             5
# user_count                          31
# ground_type                          5
# tennis_points                        6
# has_event_player_statistics          1
# crowd_sourcing_enabled               1
# has_performance_graph_feature        1
# display_inverse_home_away_teams      1
# priority                             1
# competition_type                     1
# dtype: int64

# %% [markdown]
# ### 1. MatchVenueInfo
#
# 1. `match_id`
#     * **Numerical**
#     * Showing ID of the match and seems like all the tables relate to each other with this ID
#
# 2. `city`
#     * **Categorical**
#     * Showing City for each match.
#     * This column has **38 Unique Values**
#
# 3. `stadium`
#     * **Categorical**
#     * This column shows stadium name
#     * This column has **43 Unique Values**
#
# 4. `venue_id`
#     * **Numerical**
#     * Showing ID of the venue
#
# 5. `country`
#     * **Categorical**
#     * This column has **One** Missing Value

# %%
df_venue.head()
# Out:
#    match_id        city         stadium  venue_id   country
# 0  11673958      Bogota  Cancha Central     18338  Colombia
# 1  11673962      Bogota  Cancha Central     18338  Colombia
# 2  11673963      Bogota  Cancha Central     18338  Colombia
# 3  11673993       Braga   Court Central     21510  Portugal
# 4  11674000  Charleston    Center Court     32522       USA

# %%
df_venue.columns
# Out:
# Index(['match_id', 'city', 'stadium', 'venue_id', 'country'], dtype='object')

# %%
df_venue.stadium.nunique()
# Out:
# 43

# %%
df_venue.city.nunique()
# Out:
# 38

# %%
df_venue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 763 entries, 0 to 762
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   match_id  763 non-null    int64
#  1   city      763 non-null    object
#  2   stadium   763 non-null    object
#  3   venue_id  763 non-null    int64
#  4   country   762 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 29.9+ KB

# %%
df_venue.describe()
# Out:
#            match_id      venue_id
# count  7.630000e+02    763.000000
# mean   1.169904e+07  27783.026212
# std    5.017576e+03   8823.835485
# min    1.167396e+07   2102.000000
# 25%    1.169901e+07  19072.500000
# 50%    1.169935e+07  28799.000000
# 75%    1.170152e+07  34383.000000
# max    1.170352e+07  41921.000000

# %%
df_venue.isna().sum()
# Out:
# match_id    0
# city        0
# stadium     0
# venue_id    0
# country     1
# dtype: int64

# %% [markdown]
# ### 1. MatchVenueInfo
#
# 1. `match_id`
#     * **Numerical**
#     * Showing ID of the match and seems like all the tables relate to each other with this ID
#
# 2. `home_vote`
#     * **Numerical**
#     * This column shows count of home_votes
#     * This column has **38 Unique Values**
#     * Some of the information about this column:
#         * Mean : 136.298429
#         * Min : 0
#         * Max : 8133
#         * std : 591.036442
#         * Q1 : 2
#         * Q3 : 32
#
# 3. `away_vote`
#     * **Numerical**
#     * This column shows count of away_votes
#     * This column has **43 Unique Values**
#     * Some of the information about this column:
#         * Mean : 130.712042
#         * Min : 0
#         * Max : 6851
#         * std : 521.944636
#         * Q1 : 2
#         * Q3 : 24

# %%
df_votes.head()
# Out:
#    match_id  home_vote  away_vote
# 0  11673958        554        233
# 1  11673962        909        213
# 2  11673963        399        213
# 3  11673993        744        208
# 4  11674000        461        320

# %%
df_votes.columns
# Out:
# Index(['match_id', 'home_vote', 'away_vote'], dtype='object')

# %%
df_votes.describe()
# Out:
#            match_id    home_vote    away_vote
# count  7.640000e+02   764.000000   764.000000
# mean   1.169902e+07   136.298429   130.712042
# std    5.029278e+03   591.036442   521.944636
# min    1.167396e+07     0.000000     0.000000
# 25%    1.169901e+07     2.000000     2.000000
# 50%    1.169935e+07     7.000000     5.000000
# 75%    1.170151e+07    32.250000    24.000000
# max    1.170352e+07  8133.000000  6851.000000

# %%
df_votes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 764 entries, 0 to 763
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   match_id   764 non-null    int64
#  1   home_vote  764 non-null    int64
#  2   away_vote  764 non-null    int64
# dtypes: int64(3)
# memory usage: 18.0 KB
